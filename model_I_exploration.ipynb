# %%
import numpy as np
import matplotlib.pyplot as plt
import functools as ft
from scipy.linalg import expm
from scipy.stats import unitary_group

# %% [markdown]
# # Projected mixed state ensembles: Model 1

# %%
# Some code with functions from the projected pure ensemble file

sx = np.array([[0,1],[1,0]]) ;  sy = np.array([[0,-1j],[1j,0]])

# Hamiltonian and initial state following Cotler et al.

def QIMF(N, h_x, h_y, J):

    # Single site term
    H1 = h_x * sx + h_y * sy
    # Interaction term
    H2 = J * np.kron(sx,sx)

    # Hamiltonian as a matrix
    H = np.zeros((2**N,2**N),dtype='complex128')
    for i in range(N):
        H += ft.reduce(np.kron, [np.identity(2**i), H1, np.identity(2**(N-i-1))])
    for i in range(N-2):
        H += ft.reduce(np.kron, [np.identity(2**i), H2, np.identity(2**(N-i-2))])
    
    return H

def Psi_initial(N):
    # Initial state: all |0>
    Psi0 = np.zeros(2**N)
    Psi0[0] = 1
    return Psi0

# Projected ensemble from a given states

def Get_PrEns(Psi, N_A, N_B):
    PrEns = np.empty((2**N_B, 2)).tolist()

    for i in range(2**N_B):
        PsiA = Psi.reshape(2**N_A, 2**N_B)[:,i]
        PrEns[i][0] = np.linalg.norm(PsiA) ** 2
        PrEns[i][1] = PsiA / np.linalg.norm(PsiA)
    
    return PrEns

# Haar moments

def rho_1_Haar(d):
    rho_1 = np.identity(d, dtype='complex128') / d
    return rho_1

def rho_2_Haar(d):
    rho_2 = np.zeros((d**2,d**2), dtype='complex128')
    
    # Identity
    rho_2 += np.identity(d**2, dtype='complex128')

    # Swap
    for i in range(d):
        for j in range(d):
            ket_i = np.zeros(d)
            ket_i [i] = 1
            ket_j = np.zeros(d)
            ket_j [j] = 1

            ket_ij = np.kron(ket_i, ket_j)
            ket_ji = np.kron(ket_j, ket_i)

            rho_2 += np.outer(np.conjugate(ket_ji), ket_ij)
        

    return rho_2 / (d * (d+1) )

def rho_3_Haar(d):
    rho_3 = np.zeros((d**3,d**3), dtype='complex128')

    # Identity
    rho_3 += np.identity(d**3, dtype='complex128')

    for i in range(d):
        for j in range(d):
            for k in range(d):
                ket_i = np.zeros(d)
                ket_i[i] = 1
                ket_j = np.zeros(d)
                ket_j[j] = 1
                ket_k = np.zeros(d)
                ket_k[k] = 1

                ket_ijk = ft.reduce(np.kron, [ket_i, ket_j, ket_k])

                # swaps
                ket_jik = ft.reduce(np.kron, [ket_j, ket_i, ket_k])
                ket_ikj = ft.reduce(np.kron, [ket_i, ket_k, ket_j])
                ket_kji = ft.reduce(np.kron, [ket_k, ket_j, ket_i])
                rho_3 += np.outer(np.conjugate(ket_jik), ket_ijk)
                rho_3 += np.outer(np.conjugate(ket_ikj), ket_ijk)
                rho_3 += np.outer(np.conjugate(ket_kji), ket_ijk)

                # 3-cycles
                ket_jki = ft.reduce(np.kron, [ket_j, ket_k, ket_i])
                ket_kij = ft.reduce(np.kron, [ket_k, ket_i, ket_j])
                rho_3 += np.outer(np.conjugate(ket_jki), ket_ijk)
                rho_3 += np.outer(np.conjugate(ket_kij), ket_ijk)

    return rho_3 / (d * (d+1) * (d+2))

# Moments from projected ensemble

def rho_PrEns(PrEns, k):
    
    d = np.size(PrEns[0][1])
    rho_k = np.zeros((d**k, d**k), dtype='complex128')

    for i in range(len(PrEns)):
        p_i = PrEns[i][0]
        state_i = PrEns[i][1]
        k_copies = ft.reduce(np.kron, [state_i for i in range(k)])

        rho_k += p_i * np.outer(np.conjugate(k_copies), k_copies)
    
    return rho_k

# %% [markdown]
# I will consider the simple case $N_A = 1, N_B = 1, N_C = 6$ as a starting case. So we get a projected ensemble as before on $A \otimes B$, with each state labelling a unique reduced density matrix. Then make it into a 'projected mixed ensemble' by tracing out B everywhere. Then directly calculate the average purity.

# %%
# Parameters
N_A = 1
N_B = 1
N_C = 4
h_x = 0.8090
h_y = 0.9045
J = 1
N_AB = N_A + N_B

# Hamiltonian and initial state
H = QIMF(N_AB + N_C, h_x, h_y, J)
Psi0 = Psi_initial(N_AB + N_C)

times = np.linspace(0,20,400)
purities = np.zeros(400, dtype='complex128')
third_moments = np.zeros(400, dtype='complex128')
fourth_moments = np.zeros(400, dtype='complex128')
purities[0] = 1
third_moments[0] = 1
fourth_moments[0] = 1

for i, t in enumerate(times[1:]):
    # evolve
    U = expm(-1j * t * H)
    Psi = U @ Psi0

    purity = 0
    third_moment = 0
    fourth_moment = 0

    for j in range(2**N_C):
        # Project out C
        PsiAB = Psi.reshape(2**N_AB, 2**N_C)[:,j]
        p_k = np.linalg.norm(PsiAB) ** 2
        PsiAB = PsiAB / np.linalg.norm(PsiAB)
        # Trace out B, get purity
        rhoA = np.trace(np.outer(np.conjugate(PsiAB),PsiAB).reshape(2**N_A,2**N_B,2**N_A,2**N_B), axis1=1, axis2=3)
        purity += p_k * np.trace(rhoA @ rhoA)
        third_moment += p_k * np.trace(rhoA @ rhoA @ rhoA)
        fourth_moment += p_k * np.trace(rhoA @ rhoA @ rhoA @ rhoA)

    purities[i + 1] = purity
    third_moments[i+1] = third_moment
    fourth_moments[i+1] = fourth_moment

# %%
# Plot: it works

fig = plt.figure()

plt.plot(times, purities)
plt.plot(times, third_moments)
plt.plot(times, fourth_moments)
plt.show()
# Out:
# /Users/DaanTimmers/anaconda3/envs/py311/lib/python3.11/site-packages/matplotlib/cbook/__init__.py:1369: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %% [markdown]
# ## Data gathering
#
# Now do exactly as above but for a range of system sizes. Cell below gathers all the data in about 40-50 minutes.

# %%
'''
# N = 6: {1,1,4}

# Note: definition of H depends only on total dimension, so how I divide it up is irrelevant
H = QIMF(6, h_x, h_y, J)
Psi0 = Psi_initial(6)

times = np.linspace(0,50,1000)
purities_114 = np.zeros(1000, dtype='complex128')
purities_114[0] = 1

for i, t in enumerate(times[1:]):
    U = expm(-1j * t * H)
    Psi = U @ Psi0

    N_A = 1
    N_B = 1
    N_C = 4
    N_AB = N_A + N_B
    
    purity = 0

    for j in range(2**N_C):
        PsiAB = Psi.reshape(2**N_AB, 2**N_C)[:,j]
        p_k = np.linalg.norm(PsiAB) ** 2
        PsiAB = PsiAB / np.linalg.norm(PsiAB)
        rhoA = np.trace(np.outer(np.conjugate(PsiAB),PsiAB).reshape(2**N_A,2**N_B,2**N_A,2**N_B), axis1=1, axis2=3)
        purity += p_k * np.trace(rhoA @ rhoA)

    purities_114[i + 1] = purity


# N = 7: {1,1,5}, {1,2,4}, {2,1,4}

H = QIMF(7, h_x, h_y, J)
Psi0 = Psi_initial(7)

times = np.linspace(0,50,1000)
purities_115 = np.zeros(1000, dtype='complex128')
purities_115[0] = 1
purities_124 = np.zeros(1000, dtype='complex128')
purities_124[0] = 1
purities_214 = np.zeros(1000, dtype='complex128')
purities_214[0] = 1

for i, t in enumerate(times[1:]):
    U = expm(-1j * t * H)
    Psi = U @ Psi0

    # {1,1,5}
    N_A = 1
    N_B = 1
    N_C = 5
    N_AB = N_A + N_B
    
    purity = 0

    for j in range(2**N_C):
        PsiAB = Psi.reshape(2**N_AB, 2**N_C)[:,j]
        p_k = np.linalg.norm(PsiAB) ** 2
        PsiAB = PsiAB / np.linalg.norm(PsiAB)
        rhoA = np.trace(np.outer(np.conjugate(PsiAB),PsiAB).reshape(2**N_A,2**N_B,2**N_A,2**N_B), axis1=1, axis2=3)
        purity += p_k * np.trace(rhoA @ rhoA)

    purities_115[i + 1] = purity

    # {1,2,4}
    N_A = 1
    N_B = 2
    N_C = 4
    N_AB = N_A + N_B
    
    purity = 0

    for j in range(2**N_C):
        PsiAB = Psi.reshape(2**N_AB, 2**N_C)[:,j]
        p_k = np.linalg.norm(PsiAB) ** 2
        PsiAB = PsiAB / np.linalg.norm(PsiAB)
        rhoA = np.trace(np.outer(np.conjugate(PsiAB),PsiAB).reshape(2**N_A,2**N_B,2**N_A,2**N_B), axis1=1, axis2=3)
        purity += p_k * np.trace(rhoA @ rhoA)

    purities_124[i + 1] = purity

    # {2,1,4}
    N_A = 2
    N_B = 1
    N_C = 4
    N_AB = N_A + N_B
    
    purity = 0

    for j in range(2**N_C):
        PsiAB = Psi.reshape(2**N_AB, 2**N_C)[:,j]
        p_k = np.linalg.norm(PsiAB) ** 2
        PsiAB = PsiAB / np.linalg.norm(PsiAB)
        rhoA = np.trace(np.outer(np.conjugate(PsiAB),PsiAB).reshape(2**N_A,2**N_B,2**N_A,2**N_B), axis1=1, axis2=3)
        purity += p_k * np.trace(rhoA @ rhoA)

    purities_214[i + 1] = purity


# N = 8: {1,1,6}, {1,2,5}, {2,1,5}

H = QIMF(8, h_x, h_y, J)
Psi0 = Psi_initial(8)

times = np.linspace(0,50,1000)
purities_116 = np.zeros(1000, dtype='complex128')
purities_116[0] = 1
purities_125 = np.zeros(1000, dtype='complex128')
purities_125[0] = 1
purities_215 = np.zeros(1000, dtype='complex128')
purities_215[0] = 1

for i, t in enumerate(times[1:]):
    U = expm(-1j * t * H)
    Psi = U @ Psi0

    # {1,1,6}
    N_A = 1
    N_B = 1
    N_C = 6
    N_AB = N_A + N_B
    
    purity = 0

    for j in range(2**N_C):
        PsiAB = Psi.reshape(2**N_AB, 2**N_C)[:,j]
        p_k = np.linalg.norm(PsiAB) ** 2
        PsiAB = PsiAB / np.linalg.norm(PsiAB)
        rhoA = np.trace(np.outer(np.conjugate(PsiAB),PsiAB).reshape(2**N_A,2**N_B,2**N_A,2**N_B), axis1=1, axis2=3)
        purity += p_k * np.trace(rhoA @ rhoA)

    purities_116[i + 1] = purity

    # {1,2,5}
    N_A = 1
    N_B = 2
    N_C = 5
    N_AB = N_A + N_B
    
    purity = 0

    for j in range(2**N_C):
        PsiAB = Psi.reshape(2**N_AB, 2**N_C)[:,j]
        p_k = np.linalg.norm(PsiAB) ** 2
        PsiAB = PsiAB / np.linalg.norm(PsiAB)
        rhoA = np.trace(np.outer(np.conjugate(PsiAB),PsiAB).reshape(2**N_A,2**N_B,2**N_A,2**N_B), axis1=1, axis2=3)
        purity += p_k * np.trace(rhoA @ rhoA)

    purities_125[i + 1] = purity

    # {2,1,5}
    N_A = 2
    N_B = 1
    N_C = 5
    N_AB = N_A + N_B
    
    purity = 0

    for j in range(2**N_C):
        PsiAB = Psi.reshape(2**N_AB, 2**N_C)[:,j]
        p_k = np.linalg.norm(PsiAB) ** 2
        PsiAB = PsiAB / np.linalg.norm(PsiAB)
        rhoA = np.trace(np.outer(np.conjugate(PsiAB),PsiAB).reshape(2**N_A,2**N_B,2**N_A,2**N_B), axis1=1, axis2=3)
        purity += p_k * np.trace(rhoA @ rhoA)

    purities_215[i + 1] = purity

# N = 9: {1,1,7}, {1,2,6}, {2,1,6}

H = QIMF(9, h_x, h_y, J)
Psi0 = Psi_initial(9)

times = np.linspace(0,50,1000)
purities_117 = np.zeros(1000, dtype='complex128')
purities_117[0] = 1
purities_126 = np.zeros(1000, dtype='complex128')
purities_126[0] = 1
purities_216 = np.zeros(1000, dtype='complex128')
purities_216[0] = 1

for i, t in enumerate(times[1:]):
    U = expm(-1j * t * H)
    Psi = U @ Psi0

    # {1,1,7}
    N_A = 1
    N_B = 1
    N_C = 7
    N_AB = N_A + N_B
    
    purity = 0

    for j in range(2**N_C):
        PsiAB = Psi.reshape(2**N_AB, 2**N_C)[:,j]
        p_k = np.linalg.norm(PsiAB) ** 2
        PsiAB = PsiAB / np.linalg.norm(PsiAB)
        rhoA = np.trace(np.outer(np.conjugate(PsiAB),PsiAB).reshape(2**N_A,2**N_B,2**N_A,2**N_B), axis1=1, axis2=3)
        purity += p_k * np.trace(rhoA @ rhoA)

    purities_117[i + 1] = purity

    # {1,2,6}
    N_A = 1
    N_B = 2
    N_C = 6
    N_AB = N_A + N_B
    
    purity = 0

    for j in range(2**N_C):
        PsiAB = Psi.reshape(2**N_AB, 2**N_C)[:,j]
        p_k = np.linalg.norm(PsiAB) ** 2
        PsiAB = PsiAB / np.linalg.norm(PsiAB)
        rhoA = np.trace(np.outer(np.conjugate(PsiAB),PsiAB).reshape(2**N_A,2**N_B,2**N_A,2**N_B), axis1=1, axis2=3)
        purity += p_k * np.trace(rhoA @ rhoA)

    purities_126[i + 1] = purity

    # {2,1,6}
    N_A = 2
    N_B = 1
    N_C = 6
    N_AB = N_A + N_B
    
    purity = 0

    for j in range(2**N_C):
        PsiAB = Psi.reshape(2**N_AB, 2**N_C)[:,j]
        p_k = np.linalg.norm(PsiAB) ** 2
        PsiAB = PsiAB / np.linalg.norm(PsiAB)
        rhoA = np.trace(np.outer(np.conjugate(PsiAB),PsiAB).reshape(2**N_A,2**N_B,2**N_A,2**N_B), axis1=1, axis2=3)
        purity += p_k * np.trace(rhoA @ rhoA)

    purities_216[i + 1] = purity


# N = 10: {1,1,8}, {1,2,7}, {2,1,7}

H = QIMF(10, h_x, h_y, J)
Psi0 = Psi_initial(10)

times_short = np.linspace(0,50,400)
purities_118 = np.zeros(400, dtype='complex128')
purities_118[0] = 1
purities_127 = np.zeros(400, dtype='complex128')
purities_127[0] = 1
purities_217 = np.zeros(400, dtype='complex128')
purities_217[0] = 1

for i, t in enumerate(times_short[1:]):
    U = expm(-1j * t * H)
    Psi = U @ Psi0

    # {1,1,8}
    N_A = 1
    N_B = 1
    N_C = 8
    N_AB = N_A + N_B
    
    purity = 0

    for j in range(2**N_C):
        PsiAB = Psi.reshape(2**N_AB, 2**N_C)[:,j]
        p_k = np.linalg.norm(PsiAB) ** 2
        PsiAB = PsiAB / np.linalg.norm(PsiAB)
        rhoA = np.trace(np.outer(np.conjugate(PsiAB),PsiAB).reshape(2**N_A,2**N_B,2**N_A,2**N_B), axis1=1, axis2=3)
        purity += p_k * np.trace(rhoA @ rhoA)

    purities_118[i + 1] = purity

    # {1,2,7}
    N_A = 1
    N_B = 2
    N_C = 7
    N_AB = N_A + N_B
    
    purity = 0

    for j in range(2**N_C):
        PsiAB = Psi.reshape(2**N_AB, 2**N_C)[:,j]
        p_k = np.linalg.norm(PsiAB) ** 2
        PsiAB = PsiAB / np.linalg.norm(PsiAB)
        rhoA = np.trace(np.outer(np.conjugate(PsiAB),PsiAB).reshape(2**N_A,2**N_B,2**N_A,2**N_B), axis1=1, axis2=3)
        purity += p_k * np.trace(rhoA @ rhoA)

    purities_127[i + 1] = purity

    # {2,1,7}
    N_A = 2
    N_B = 1
    N_C = 7
    N_AB = N_A + N_B
    
    purity = 0

    for j in range(2**N_C):
        PsiAB = Psi.reshape(2**N_AB, 2**N_C)[:,j]
        p_k = np.linalg.norm(PsiAB) ** 2
        PsiAB = PsiAB / np.linalg.norm(PsiAB)
        rhoA = np.trace(np.outer(np.conjugate(PsiAB),PsiAB).reshape(2**N_A,2**N_B,2**N_A,2**N_B), axis1=1, axis2=3)
        purity += p_k * np.trace(rhoA @ rhoA)

    purities_217[i + 1] = purity


np.savez('Purity_timeseries',
         times=times,
         times_short=times_short,
         purities_114=purities_114,
         purities_115=purities_115,
         purities_116=purities_116,
         purities_117=purities_117,
         purities_118=purities_118,
         purities_214=purities_214,
         purities_215=purities_215,
         purities_216=purities_216,
         purities_217=purities_217,
         purities_124=purities_124,
         purities_125=purities_125,
         purities_126=purities_126,
         purities_127=purities_127)


'''
# Out:
# "\n# N = 6: {1,1,4}\n\n# Note: definition of H depends only on total dimension, so how I divide it up is irrelevant\nH = QIMF(6, h_x, h_y, J)\nPsi0 = Psi_initial(6)\n\ntimes = np.linspace(0,50,1000)\npurities_114 = np.zeros(1000, dtype='complex128')\npurities_114[0] = 1\n\nfor i, t in enumerate(times[1:]):\n    U = expm(-1j * t * H)\n    Psi = U @ Psi0\n\n    N_A = 1\n    N_B = 1\n    N_C = 4\n    N_AB = N_A + N_B\n    \n    purity = 0\n\n    for j in range(2**N_C):\n        PsiAB = Psi.reshape(2**N_AB, 2**N_C)[:,j]\n        p_k = np.linalg.norm(PsiAB) ** 2\n        PsiAB = PsiAB / np.linalg.norm(PsiAB)\n        rhoA = np.trace(np.outer(np.conjugate(PsiAB),PsiAB).reshape(2**N_A,2**N_B,2**N_A,2**N_B), axis1=1, axis2=3)\n        purity += p_k * np.trace(rhoA @ rhoA)\n\n    purities_114[i + 1] = purity\n\n\n# N = 7: {1,1,5}, {1,2,4}, {2,1,4}\n\nH = QIMF(7, h_x, h_y, J)\nPsi0 = Psi_initial(7)\n\ntimes = np.linspace(0,50,1000)\npurities_115 = np.zeros(1000, dtype='complex128')\npurities_1
# ...

# %% [markdown]
# Higher moments timeseries (below cell took 37 minutes to run):

# %%
'''
# N = 6: {1,1,4}

# Note: definition of H depends only on total dimension, so how I divide it up is irrelevant
H = QIMF(6, h_x, h_y, J)
Psi0 = Psi_initial(6)

times = np.linspace(0,50,1000)
third_114 = np.zeros(1000, dtype='complex128')
third_114[0] = 1
fourth_114 = np.zeros(1000, dtype='complex128')
fourth_114[0] = 1

for i, t in enumerate(times[1:]):
    U = expm(-1j * t * H)
    Psi = U @ Psi0

    N_A = 1
    N_B = 1
    N_C = 4
    N_AB = N_A + N_B
    
    third = 0
    fourth = 0

    for j in range(2**N_C):
        PsiAB = Psi.reshape(2**N_AB, 2**N_C)[:,j]
        p_k = np.linalg.norm(PsiAB) ** 2
        PsiAB = PsiAB / np.linalg.norm(PsiAB)
        rhoA = np.trace(np.outer(np.conjugate(PsiAB),PsiAB).reshape(2**N_A,2**N_B,2**N_A,2**N_B), axis1=1, axis2=3)
        
        third += p_k * np.trace(rhoA @ rhoA @ rhoA)
        fourth += p_k * np.trace(rhoA @ rhoA @ rhoA @ rhoA)

    third_114[i + 1] = third
    fourth_114[i + 1] = fourth


# N = 7: {1,1,5}, {1,2,4}, {2,1,4}

H = QIMF(7, h_x, h_y, J)
Psi0 = Psi_initial(7)

times = np.linspace(0,50,1000)
third_124 = np.zeros(1000, dtype='complex128')
third_124[0] = 1
fourth_124 = np.zeros(1000, dtype='complex128')
fourth_124[0] = 1
third_214 = np.zeros(1000, dtype='complex128')
third_214[0] = 1
fourth_214 = np.zeros(1000, dtype='complex128')
fourth_214[0] = 1
third_115 = np.zeros(1000, dtype='complex128')
third_115[0] = 1
fourth_115 = np.zeros(1000, dtype='complex128')
fourth_115[0] = 1

for i, t in enumerate(times[1:]):
    U = expm(-1j * t * H)
    Psi = U @ Psi0

    # {1,1,5}
    N_A = 1
    N_B = 1
    N_C = 5
    N_AB = N_A + N_B
    
    third = 0
    fourth = 0

    for j in range(2**N_C):
        PsiAB = Psi.reshape(2**N_AB, 2**N_C)[:,j]
        p_k = np.linalg.norm(PsiAB) ** 2
        PsiAB = PsiAB / np.linalg.norm(PsiAB)
        rhoA = np.trace(np.outer(np.conjugate(PsiAB),PsiAB).reshape(2**N_A,2**N_B,2**N_A,2**N_B), axis1=1, axis2=3)
        
        third += p_k * np.trace(rhoA @ rhoA @ rhoA)
        fourth += p_k * np.trace(rhoA @ rhoA @ rhoA @ rhoA)

    third_115[i + 1] = third
    fourth_115[i+1] = fourth

    # {1,2,4}
    N_A = 1
    N_B = 2
    N_C = 4
    N_AB = N_A + N_B
    
    third = 0
    fourth = 0

    for j in range(2**N_C):
        PsiAB = Psi.reshape(2**N_AB, 2**N_C)[:,j]
        p_k = np.linalg.norm(PsiAB) ** 2
        PsiAB = PsiAB / np.linalg.norm(PsiAB)
        rhoA = np.trace(np.outer(np.conjugate(PsiAB),PsiAB).reshape(2**N_A,2**N_B,2**N_A,2**N_B), axis1=1, axis2=3)
        
        third += p_k * np.trace(rhoA @ rhoA @ rhoA)
        fourth += p_k * np.trace(rhoA @ rhoA @ rhoA @ rhoA)

    third_124[i + 1] = third
    fourth_124[i+1] = fourth

    # {2,1,4}
    N_A = 2
    N_B = 1
    N_C = 4
    N_AB = N_A + N_B
    
    third = 0
    fourth = 0

    for j in range(2**N_C):
        PsiAB = Psi.reshape(2**N_AB, 2**N_C)[:,j]
        p_k = np.linalg.norm(PsiAB) ** 2
        PsiAB = PsiAB / np.linalg.norm(PsiAB)
        rhoA = np.trace(np.outer(np.conjugate(PsiAB),PsiAB).reshape(2**N_A,2**N_B,2**N_A,2**N_B), axis1=1, axis2=3)
        
        third += p_k * np.trace(rhoA @ rhoA @ rhoA)
        fourth += p_k * np.trace(rhoA @ rhoA @ rhoA @ rhoA)

    third_214[i+1] = third
    fourth_214[i+1] = fourth


# N = 8: {1,1,6}, {1,2,5}, {2,1,5}

H = QIMF(8, h_x, h_y, J)
Psi0 = Psi_initial(8)

times = np.linspace(0,50,1000)
third_125 = np.zeros(1000, dtype='complex128')
third_125[0] = 1
fourth_125 = np.zeros(1000, dtype='complex128')
fourth_125[0] = 1
third_215 = np.zeros(1000, dtype='complex128')
third_215[0] = 1
fourth_215 = np.zeros(1000, dtype='complex128')
fourth_215[0] = 1
third_116 = np.zeros(1000, dtype='complex128')
third_116[0] = 1
fourth_116 = np.zeros(1000, dtype='complex128')
fourth_116[0] = 1

for i, t in enumerate(times[1:]):
    U = expm(-1j * t * H)
    Psi = U @ Psi0

    # {1,1,6}
    N_A = 1
    N_B = 1
    N_C = 6
    N_AB = N_A + N_B
    
    third = 0
    fourth = 0

    for j in range(2**N_C):
        PsiAB = Psi.reshape(2**N_AB, 2**N_C)[:,j]
        p_k = np.linalg.norm(PsiAB) ** 2
        PsiAB = PsiAB / np.linalg.norm(PsiAB)
        rhoA = np.trace(np.outer(np.conjugate(PsiAB),PsiAB).reshape(2**N_A,2**N_B,2**N_A,2**N_B), axis1=1, axis2=3)
        
        third += p_k * np.trace(rhoA @ rhoA @ rhoA)
        fourth += p_k * np.trace(rhoA @ rhoA @ rhoA @ rhoA)

    third_116[i + 1] = third
    fourth_116[i+1] = fourth

    # {1,2,5}
    N_A = 1
    N_B = 2
    N_C = 5
    N_AB = N_A + N_B

    third = 0
    fourth = 0

    for j in range(2**N_C):
        PsiAB = Psi.reshape(2**N_AB, 2**N_C)[:,j]
        p_k = np.linalg.norm(PsiAB) ** 2
        PsiAB = PsiAB / np.linalg.norm(PsiAB)
        rhoA = np.trace(np.outer(np.conjugate(PsiAB),PsiAB).reshape(2**N_A,2**N_B,2**N_A,2**N_B), axis1=1, axis2=3)
        
        third += p_k * np.trace(rhoA @ rhoA @ rhoA)
        fourth += p_k * np.trace(rhoA @ rhoA @ rhoA @ rhoA)

    third_125[i + 1] = third
    fourth_125[i+1] = fourth

    # {2,1,5}
    N_A = 2
    N_B = 1
    N_C = 5
    N_AB = N_A + N_B
    
    third = 0
    fourth = 0

    for j in range(2**N_C):
        PsiAB = Psi.reshape(2**N_AB, 2**N_C)[:,j]
        p_k = np.linalg.norm(PsiAB) ** 2
        PsiAB = PsiAB / np.linalg.norm(PsiAB)
        rhoA = np.trace(np.outer(np.conjugate(PsiAB),PsiAB).reshape(2**N_A,2**N_B,2**N_A,2**N_B), axis1=1, axis2=3)
        
        third += p_k * np.trace(rhoA @ rhoA @ rhoA)
        fourth += p_k * np.trace(rhoA @ rhoA @ rhoA @ rhoA)

    third_215[i + 1] = third
    fourth_215[i+1] = fourth

# N = 9: {1,1,7}, {1,2,6}, {2,1,6}

H = QIMF(9, h_x, h_y, J)
Psi0 = Psi_initial(9)

times = np.linspace(0,50,1000)
third_126 = np.zeros(1000, dtype='complex128')
third_126[0] = 1
fourth_126 = np.zeros(1000, dtype='complex128')
fourth_126[0] = 1
third_216 = np.zeros(1000, dtype='complex128')
third_216[0] = 1
fourth_216 = np.zeros(1000, dtype='complex128')
fourth_216[0] = 1
third_117 = np.zeros(1000, dtype='complex128')
third_117[0] = 1
fourth_117 = np.zeros(1000, dtype='complex128')
fourth_117[0] = 1

for i, t in enumerate(times[1:]):
    U = expm(-1j * t * H)
    Psi = U @ Psi0

    # {1,1,7}
    N_A = 1
    N_B = 1
    N_C = 7
    N_AB = N_A + N_B
    
    third = 0
    fourth = 0

    for j in range(2**N_C):
        PsiAB = Psi.reshape(2**N_AB, 2**N_C)[:,j]
        p_k = np.linalg.norm(PsiAB) ** 2
        PsiAB = PsiAB / np.linalg.norm(PsiAB)
        rhoA = np.trace(np.outer(np.conjugate(PsiAB),PsiAB).reshape(2**N_A,2**N_B,2**N_A,2**N_B), axis1=1, axis2=3)
        
        third += p_k * np.trace(rhoA @ rhoA @ rhoA)
        fourth += p_k * np.trace(rhoA @ rhoA @ rhoA @ rhoA)

    third_117[i + 1] = third
    fourth_117[i+1] = fourth

    # {1,2,6}
    N_A = 1
    N_B = 2
    N_C = 6
    N_AB = N_A + N_B
    
    third = 0
    fourth = 0

    for j in range(2**N_C):
        PsiAB = Psi.reshape(2**N_AB, 2**N_C)[:,j]
        p_k = np.linalg.norm(PsiAB) ** 2
        PsiAB = PsiAB / np.linalg.norm(PsiAB)
        rhoA = np.trace(np.outer(np.conjugate(PsiAB),PsiAB).reshape(2**N_A,2**N_B,2**N_A,2**N_B), axis1=1, axis2=3)
        
        third += p_k * np.trace(rhoA @ rhoA @ rhoA)
        fourth += p_k * np.trace(rhoA @ rhoA @ rhoA @ rhoA)

    third_126[i + 1] = third
    fourth_126[i+1] = fourth

    # {2,1,6}
    N_A = 2
    N_B = 1
    N_C = 6
    N_AB = N_A + N_B
    
    third = 0
    fourth = 0

    for j in range(2**N_C):
        PsiAB = Psi.reshape(2**N_AB, 2**N_C)[:,j]
        p_k = np.linalg.norm(PsiAB) ** 2
        PsiAB = PsiAB / np.linalg.norm(PsiAB)
        rhoA = np.trace(np.outer(np.conjugate(PsiAB),PsiAB).reshape(2**N_A,2**N_B,2**N_A,2**N_B), axis1=1, axis2=3)
        
        third += p_k * np.trace(rhoA @ rhoA @ rhoA)
        fourth += p_k * np.trace(rhoA @ rhoA @ rhoA @ rhoA)

    third_216[i + 1] = third
    fourth_216[i+1] = fourth


# N = 10: {1,1,8}, {1,2,7}, {2,1,7}

H = QIMF(10, h_x, h_y, J)
Psi0 = Psi_initial(10)

times_short = np.linspace(0,50,400)
third_127 = np.zeros(1000, dtype='complex128')
third_127[0] = 1
fourth_127 = np.zeros(1000, dtype='complex128')
fourth_127[0] = 1
third_217 = np.zeros(1000, dtype='complex128')
third_217[0] = 1
fourth_217 = np.zeros(1000, dtype='complex128')
fourth_217[0] = 1
third_118 = np.zeros(1000, dtype='complex128')
third_118[0] = 1
fourth_118 = np.zeros(1000, dtype='complex128')
fourth_118[0] = 1

for i, t in enumerate(times_short[1:]):
    U = expm(-1j * t * H)
    Psi = U @ Psi0

    # {1,1,8}
    N_A = 1
    N_B = 1
    N_C = 8
    N_AB = N_A + N_B
    
    third = 0
    fourth = 0

    for j in range(2**N_C):
        PsiAB = Psi.reshape(2**N_AB, 2**N_C)[:,j]
        p_k = np.linalg.norm(PsiAB) ** 2
        PsiAB = PsiAB / np.linalg.norm(PsiAB)
        rhoA = np.trace(np.outer(np.conjugate(PsiAB),PsiAB).reshape(2**N_A,2**N_B,2**N_A,2**N_B), axis1=1, axis2=3)
        
        third += p_k * np.trace(rhoA @ rhoA @ rhoA)
        fourth += p_k * np.trace(rhoA @ rhoA @ rhoA @ rhoA)

    third_118[i + 1] = third
    fourth_118[i+1] = fourth

    # {1,2,7}
    N_A = 1
    N_B = 2
    N_C = 7
    N_AB = N_A + N_B
    
    third = 0
    fourth = 0

    for j in range(2**N_C):
        PsiAB = Psi.reshape(2**N_AB, 2**N_C)[:,j]
        p_k = np.linalg.norm(PsiAB) ** 2
        PsiAB = PsiAB / np.linalg.norm(PsiAB)
        rhoA = np.trace(np.outer(np.conjugate(PsiAB),PsiAB).reshape(2**N_A,2**N_B,2**N_A,2**N_B), axis1=1, axis2=3)
        
        third += p_k * np.trace(rhoA @ rhoA @ rhoA)
        fourth += p_k * np.trace(rhoA @ rhoA @ rhoA @ rhoA)

    third_127[i + 1] = third
    fourth_127[i+1] = fourth

    # {2,1,7}
    N_A = 2
    N_B = 1
    N_C = 7
    N_AB = N_A + N_B
    
    third = 0
    fourth = 0

    for j in range(2**N_C):
        PsiAB = Psi.reshape(2**N_AB, 2**N_C)[:,j]
        p_k = np.linalg.norm(PsiAB) ** 2
        PsiAB = PsiAB / np.linalg.norm(PsiAB)
        rhoA = np.trace(np.outer(np.conjugate(PsiAB),PsiAB).reshape(2**N_A,2**N_B,2**N_A,2**N_B), axis1=1, axis2=3)
        
        third += p_k * np.trace(rhoA @ rhoA @ rhoA)
        fourth += p_k * np.trace(rhoA @ rhoA @ rhoA @ rhoA)

    third_217[i + 1] = third
    fourth_217[i+1] = fourth


np.savez('Higher_moments_timeseries',
         times=times,
         times_short=times_short,
         third_114=third_114,
         third_115=third_115,
         third_116=third_116,
         third_117=third_117,
         third_118=third_118,
         third_214=third_214,
         third_215=third_215,
         third_216=third_216,
         third_217=third_217,
         third_124=third_124,
         third_125=third_125,
         third_126=third_126,
         third_127=third_127,
         fourth_114=fourth_114,
         fourth_115=fourth_115,
         fourth_116=fourth_116,
         fourth_117=fourth_117,
         fourth_118=fourth_118,
         fourth_214=fourth_214,
         fourth_215=fourth_215,
         fourth_216=fourth_216,
         fourth_217=fourth_217,
         fourth_124=fourth_124,
         fourth_125=fourth_125,
         fourth_126=fourth_126,
         fourth_127=fourth_127)

'''

# %% [markdown]
# ## More data: empirical Haar
#
# Code below strongly suggests that for the Haar ensemble of states on $\mathcal{H}_A \otimes \mathcal{H}_B$ we have:
# - $P = 4/5$ for $N_A = 1$, $N_B = 1$;
# - $P = 2/3$ for $N_A = 2$, $N_B = 1$ and $N_A = 1$, $N_B = 2$.

# %%
# N_A = 1, N_B = 1

purity_11 = 0

for i in range(100000):
    Psi0 = Psi_initial(2)
    U = unitary_group.rvs(4)
    Psi = U @ Psi0

    rhoA = np.trace(np.outer(np.conjugate(Psi), Psi).reshape(2,2,2,2), axis1=1, axis2=3)

    purity_11 += np.trace(rhoA @ rhoA)

purity_11 /= 100000

# N_A, N_B = 1, 2 and 2, 1
purity_12 = 0
purity_21 = 0

for i in range(100000):
    Psi0 = Psi_initial(3)
    U = unitary_group.rvs(8)
    Psi = U @ Psi0

    rhoA = np.trace(np.outer(np.conjugate(Psi), Psi).reshape(2,4,2,4), axis1=1, axis2=3)
    purity_12 += np.trace(rhoA @ rhoA)

    rhoA = np.trace(np.outer(np.conjugate(Psi), Psi).reshape(4,2,4,2), axis1=1, axis2=3)
    purity_21 += np.trace(rhoA @ rhoA)

purity_12 /= 100000
purity_21 /= 100000

print(purity_11)
print(purity_12)
print(purity_21)
# Out:
# (0.7996927338134923+0j)
# (0.6664382016131121+0j)
# (0.6662733083711402+0j)

# %% [markdown]
# ## Plots and analysis
#
# These are the timeseries plots with empirical Haar averages for the three different cases, and the late time averages and standard deviations.

# %%
purity_timeseries = np.load('Purity_timeseries.npz')

# Let's get late-time averages and standard deviations, from t = 10 to t = 50, in arrays labelled averages_N_A N_B

averages_11 = np.real([ [np.average(purity_timeseries['purities_114'][200:]), np.std(purity_timeseries['purities_114'][200:])],
                        [np.average(purity_timeseries['purities_115'][200:]), np.std(purity_timeseries['purities_115'][200:])],
                        [np.average(purity_timeseries['purities_116'][200:]), np.std(purity_timeseries['purities_116'][200:])],
                        [np.average(purity_timeseries['purities_117'][200:]), np.std(purity_timeseries['purities_117'][200:])],
                        [np.average(purity_timeseries['purities_118'][80:]), np.std(purity_timeseries['purities_118'][80:])]])

averages_21 = np.real([[ np.average(purity_timeseries['purities_214'][200:]), np.std(purity_timeseries['purities_214'][200:])],
                        [np.average(purity_timeseries['purities_215'][200:]), np.std(purity_timeseries['purities_215'][200:])],
                        [np.average(purity_timeseries['purities_216'][200:]), np.std(purity_timeseries['purities_216'][200:])],
                        [np.average(purity_timeseries['purities_217'][80:]), np.std(purity_timeseries['purities_217'][80:])]])

averages_12 = np.real([ [np.average(purity_timeseries['purities_124'][200:]), np.std(purity_timeseries['purities_124'][200:])],
                        [np.average(purity_timeseries['purities_125'][200:]), np.std(purity_timeseries['purities_125'][200:])],
                        [np.average(purity_timeseries['purities_126'][200:]), np.std(purity_timeseries['purities_126'][200:])],
                        [np.average(purity_timeseries['purities_127'][80:]), np.std(purity_timeseries['purities_127'][80:])]])


print(averages_11)
print(averages_12)
print(averages_21)
# Out:
# [[0.81417377 0.04857969]
#  [0.80908575 0.03697972]
#  [0.80528268 0.02927969]
#  [0.80656386 0.01823669]
#  [0.80437636 0.01359948]]
# [[0.67870748 0.04345396]
#  [0.67728139 0.0315366 ]
#  [0.6714034  0.01886024]
#  [0.67134567 0.01419713]]
# [[0.67779192 0.04391623]
#  [0.67662043 0.02672575]
#  [0.67370284 0.01864343]
#  [0.6696363  0.01312484]]

# %%
fig, axes = plt.subplots(nrows=1,ncols=3,figsize=(10,4))

axes[0].plot(purity_timeseries['times'], purity_timeseries['purities_114'], color='y', alpha=0.1)
axes[0].plot(purity_timeseries['times'], purity_timeseries['purities_115'], color='y', alpha=0.2)
axes[0].plot(purity_timeseries['times'], purity_timeseries['purities_116'], color='y', alpha=0.4)
axes[0].plot(purity_timeseries['times'], purity_timeseries['purities_117'], color='y', alpha=0.6)
axes[0].plot(purity_timeseries['times_short'], purity_timeseries['purities_118'], color='y', alpha=1)
axes[0].plot(purity_timeseries['times'], [0.8 for i in range(len(purity_timeseries['times']))], color='k', linestyle='dotted')
axes[0].set_ylim(0.55,1.05)
axes[0].set_ylabel('Purity')
axes[0].set_xlabel('$t$')
axes[0].set_title('$N_A = 1, N_B = 1$')
#axes[0].set_xscale('log')

axes[1].plot(purity_timeseries['times'], purity_timeseries['purities_124'], color='r', alpha=0.2)
axes[1].plot(purity_timeseries['times'], purity_timeseries['purities_125'], color='r', alpha=0.4)
axes[1].plot(purity_timeseries['times'], purity_timeseries['purities_126'], color='r', alpha=0.6)
axes[1].plot(purity_timeseries['times_short'], purity_timeseries['purities_127'], color='r', alpha=1)
axes[1].plot(purity_timeseries['times'], [2/3 for i in range(len(purity_timeseries['times']))], color='k', linestyle='dotted')
axes[1].set_ylim(0.55,1.05)
axes[1].set_xlabel('$t$')
axes[1].set_title('$N_A = 1, N_B = 2$')
#axes[1].set_xscale('log')

axes[2].plot(purity_timeseries['times'], purity_timeseries['purities_214'], color='m', alpha=0.2)
axes[2].plot(purity_timeseries['times'], purity_timeseries['purities_215'], color='m', alpha=0.4)
axes[2].plot(purity_timeseries['times'], purity_timeseries['purities_216'], color='m', alpha=0.6)
axes[2].plot(purity_timeseries['times_short'], purity_timeseries['purities_217'], color='m', alpha=1)
axes[2].plot(purity_timeseries['times'], [2/3 for i in range(len(purity_timeseries['times']))], color='k', linestyle='dotted')
axes[2].set_ylim(0.55,1.05)
axes[2].set_xlabel('$t$')
axes[2].set_title('$N_A = 2, N_B = 1$')
#axes[2].set_xscale('log')
# Out:
# Text(0.5, 1.0, '$N_A = 2, N_B = 1$')

# %%
d_A = 2
d_B = 2
d = d_A * d_B
print(d_A ** 3 + d_B ** 3 + 6 * d_A * d_B ** 2 + 6 * d_A ** 2 * d_B + 5* d_A + 5* d_B)
print((d+1) * (d+2) * (d+3))
# Out:
# 132
# 210

# %%
moments_timeseries = np.load('Higher_moments_timeseries.npz')
fig, axes = plt.subplots(nrows=2,ncols=3,figsize=(10,9))

axes[0,0].plot(moments_timeseries['times'], moments_timeseries['third_114'], color='y', alpha=0.1)
axes[0,0].plot(moments_timeseries['times'], moments_timeseries['third_115'], color='y', alpha=0.2)
axes[0,0].plot(moments_timeseries['times'], moments_timeseries['third_116'], color='y', alpha=0.4)
axes[0,0].plot(moments_timeseries['times'], moments_timeseries['third_117'], color='y', alpha=0.6)
axes[0,0].plot(moments_timeseries['times_short'], moments_timeseries['third_118'][:400], color='y', alpha=1)
axes[0,0].plot(moments_timeseries['times'], [0.7 for i in range(len(moments_timeseries['times']))], color='k', linestyle='dotted')
# axes[0,0].set_ylim(0.55,1.05)
axes[0,0].set_ylabel('Third moment')
axes[0,0].set_xlabel('$t$')
axes[0,0].set_title('$N_A = 1, N_B = 1$')
#axes[0].set_xscale('log')

axes[0,1].plot(moments_timeseries['times'], moments_timeseries['third_124'], color='r', alpha=0.2)
axes[0,1].plot(moments_timeseries['times'], moments_timeseries['third_125'], color='r', alpha=0.4)
axes[0,1].plot(moments_timeseries['times'], moments_timeseries['third_126'], color='r', alpha=0.6)
axes[0,1].plot(moments_timeseries['times_short'], moments_timeseries['third_127'][:400], color='r', alpha=1)
axes[0,1].plot(moments_timeseries['times'], [0.5 for i in range(len(moments_timeseries['times']))], color='k', linestyle='dotted')
# axes[1].set_ylim(0.55,1.05)
axes[0,1].set_xlabel('$t$')
axes[0,1].set_title('$N_A = 1, N_B = 2$')
# axes[0,1].set_xscale('log')

axes[0,2].plot(moments_timeseries['times'], moments_timeseries['third_214'], color='m', alpha=0.2)
axes[0,2].plot(moments_timeseries['times'], moments_timeseries['third_215'], color='m', alpha=0.4)
axes[0,2].plot(moments_timeseries['times'], moments_timeseries['third_216'], color='m', alpha=0.6)
axes[0,2].plot(moments_timeseries['times_short'], moments_timeseries['third_217'][:400], color='m', alpha=1)
axes[0,2].plot(moments_timeseries['times'], [0.5 for i in range(len(moments_timeseries['times']))], color='k', linestyle='dotted')
# axes[0,2].set_ylim(0.55,1.05)
axes[0,2].set_xlabel('$t$')
axes[0,2].set_title('$N_A = 2, N_B = 1$')
#axes[2].set_xscale('log')

axes[1,0].plot(moments_timeseries['times'], moments_timeseries['fourth_114'], color='y', alpha=0.1)
axes[1,0].plot(moments_timeseries['times'], moments_timeseries['fourth_115'], color='y', alpha=0.2)
axes[1,0].plot(moments_timeseries['times'], moments_timeseries['fourth_116'], color='y', alpha=0.4)
axes[1,0].plot(moments_timeseries['times'], moments_timeseries['fourth_117'], color='y', alpha=0.6)
axes[1,0].plot(moments_timeseries['times_short'], moments_timeseries['fourth_118'][:400], color='y', alpha=1)
axes[1,0].plot(purity_timeseries['times'], [66/105 for i in range(len(moments_timeseries['times']))], color='k', linestyle='dotted')
# axes[0,0].set_ylim(0.55,1.05)
axes[1,0].set_ylabel('Fourth moment')
axes[1,0].set_xlabel('$t$')
# axes[1,0].set_title('$N_A = 1, N_B = 1$')
#axes[0].set_xscale('log')

axes[1,1].plot(moments_timeseries['times'], moments_timeseries['fourth_124'], color='r', alpha=0.2)
axes[1,1].plot(moments_timeseries['times'], moments_timeseries['fourth_125'], color='r', alpha=0.4)
axes[1,1].plot(moments_timeseries['times'], moments_timeseries['fourth_126'], color='r', alpha=0.6)
axes[1,1].plot(moments_timeseries['times_short'], moments_timeseries['fourth_127'][:400], color='r', alpha=1)
axes[1,1].plot(moments_timeseries['times'], [39/99 for i in range(len(moments_timeseries['times']))], color='k', linestyle='dotted')
# axes[1].set_ylim(0.55,1.05)
axes[1,1].set_xlabel('$t$')
# axes[1,1].set_title('$N_A = 1, N_B = 2$')
# axes[0,1].set_xscale('log')

axes[1,2].plot(moments_timeseries['times'], moments_timeseries['fourth_214'], color='m', alpha=0.2)
axes[1,2].plot(moments_timeseries['times'], moments_timeseries['fourth_215'], color='m', alpha=0.4)
axes[1,2].plot(moments_timeseries['times'], moments_timeseries['fourth_216'], color='m', alpha=0.6)
axes[1,2].plot(moments_timeseries['times_short'], moments_timeseries['fourth_217'][:400], color='m', alpha=1)
axes[1,2].plot(moments_timeseries['times'], [39/99 for i in range(len(moments_timeseries['times']))], color='k', linestyle='dotted')
# axes[0,2].set_ylim(0.55,1.05)
axes[1,2].set_xlabel('$t$')
# axes[1,2].set_title('$N_A = 2, N_B = 1$')
#axes[2].set_xscale('log')
# Out:
# Text(0.5, 0, '$t$')

# %% [markdown]
# ## Investigation: more empirical Haar
#
# Let's investigate the Haar result empirically but for a larger range of dimensions $d_A$ and $d_B$. Both must be at least 2 to be non-trivial. Let's have them both go up to 8. Only do half of the work because there is an evident symmetry.

# %%
# Note: this takes pretty long, results all in overleaf (converted to fractions)
'''
for d_A in range(2,9):
    for d_B in range(d_A,9):
        d = d_A * d_B
        psi0 = np.zeros(d)
        psi0[0] = 1
        
        purity = 0
        for i in range(100000):
            U = unitary_group.rvs(d)    
            psi = U @ psi0
            rhoA = np.trace(np.outer(np.conjugate(psi), psi).reshape(d_A, d_B, d_A, d_B), axis1=1, axis2=3)
            purity += np.trace(rhoA @ rhoA)
        
        print(f'd_A = {d_A}, d_B = {d_B}, P = {np.real(purity)/100000}')
'''
# Out:
# "\nfor d_A in range(2,9):\n    for d_B in range(d_A,9):\n        d = d_A * d_B\n        psi0 = np.zeros(d)\n        psi0[0] = 1\n        \n        purity = 0\n        for i in range(100000):\n            U = unitary_group.rvs(d)    \n            psi = U @ psi0\n            rhoA = np.trace(np.outer(np.conjugate(psi), psi).reshape(d_A, d_B, d_A, d_B), axis1=1, axis2=3)\n            purity += np.trace(rhoA @ rhoA)\n        \n        print(f'd_A = {d_A}, d_B = {d_B}, P = {np.real(purity)/100000}')\n"

# %% [markdown]
# Now the same thing, for fewer dimensions, to check my formulae for the third and fourth moments.

# %%
# Third and fourth moment formula
for d_A in range(2,6):
    for d_B in range(d_A,6):
        d = d_A * d_B
        psi0 = np.zeros(d)
        psi0[0] = 1
        
        third_moment = 0
        fourth_moment = 0
        for i in range(100000):
            U = unitary_group.rvs(d)    
            psi = U @ psi0
            rhoA = np.trace(np.outer(np.conjugate(psi), psi).reshape(d_A, d_B, d_A, d_B), axis1=1, axis2=3)
            third_moment += np.trace(rhoA @ rhoA @ rhoA)
            fourth_moment += np.trace(rhoA @ rhoA @ rhoA @ rhoA)
        
        third_expected = (1 + 3 * d_A * d_B + d_A ** 2 + d_B ** 2) / ((d+1) * (d+2))
        fourth_expected = (d_A ** 3 + d_B ** 3 + 6 * d_A * d_B ** 2 + 6 * d_A ** 2 * d_B + 5* d_A + 5* d_B) / ((d+1) * (d+2) * (d+3))
        
        print(f'd_A = {d_A}, d_B = {d_B}')
        print(f'P_3 = {np.real(third_moment)/100000}, expected P_3 = {third_expected}')
        print(f'P_4 = {np.real(fourth_moment)/100000}, expected P_4 = {fourth_expected}')
# Out:
# d_A = 2, d_B = 2
# P_3 = 0.7003779709177806, expected P_3 = 0.7
# P_4 = 0.6290445985608225, expected P_4 = 0.6285714285714286
# d_A = 2, d_B = 3
# P_3 = 0.5711304081199601, expected P_3 = 0.5714285714285714
# P_4 = 0.4758532417615665, expected P_4 = 0.47619047619047616
# d_A = 2, d_B = 4
# P_3 = 0.5008546554595283, expected P_3 = 0.5
# P_4 = 0.39490893402418903, expected P_4 = 0.3939393939393939
# d_A = 2, d_B = 5
# P_3 = 0.45457574402753315, expected P_3 = 0.45454545454545453
# P_4 = 0.3427112579349642, expected P_4 = 0.34265734265734266
# d_A = 3, d_B = 3
# P_3 = 0.4179257982714417, expected P_3 = 0.41818181818181815
# P_4 = 0.3087930523667494, expected P_4 = 0.3090909090909091
# d_A = 3, d_B = 4
# P_3 = 0.34095888326823626, expected P_3 = 0.34065934065934067
# P_4 = 0.23107439003795288, expected P_4 = 0.23076923076923078
# d_A = 3, d_B = 5
# P_3 = 0.2937113555206291, expected P_3 = 0.29411764705882354
# P_4 = 0.18589074667784217, expected P_4 = 0.18627450980392157
# ...
